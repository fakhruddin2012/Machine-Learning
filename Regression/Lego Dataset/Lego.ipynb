# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('lego.csv')

# %%
df.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0    19       29.99            2          277               4.0
# 1    19       19.99            2          168               4.0
# 2    19       12.99           11           74               4.3
# 3     5       99.99           23         1032               3.6
# 4     5       79.99           14          744               3.2
#
#    review_difficulty  star_rating  theme_name  val_star_rating  country
# 0                  0          4.5           0              4.0       20
# 1                  2          5.0           0              4.0       20
# 2                  2          4.3           0              4.1       20
# 3                  0          4.6           1              4.3       20
# 4                  1          4.6           1              4.1       20

# %%
df.shape
# Out:
# (12261, 10)

# %%
df.isna().sum()
# Out:
# ages                 0
# list_price           0
# num_reviews          0
# piece_count          0
# play_star_rating     0
# review_difficulty    0
# star_rating          0
# theme_name           0
# val_star_rating      0
# country              0
# dtype: int64

# %%
df.describe()
# Out:
#               ages    list_price   num_reviews   piece_count  \
# count  12261.00000  12261.000000  12261.000000  12261.000000
# mean      16.68828     65.141998     14.603050    493.405921
# std        8.21868     91.980429     34.356847    825.364580
# min        0.00000      2.272400      0.000000      1.000000
# 25%       11.00000     19.990000      1.000000     97.000000
# 50%       19.00000     36.587800      4.000000    216.000000
# 75%       23.00000     70.192200     11.000000    544.000000
# max       30.00000   1104.870000    367.000000   7541.000000
#
#        play_star_rating  review_difficulty   star_rating    theme_name  \
# count      12261.000000       12261.000000  12261.000000  12261.000000
# mean           3.709689           1.988826      3.917698     20.523367
# std            1.641130           1.787565      1.603276     11.990176
# min            0.000000           0.000000      0.000000      0.000000
# 25%            3.600000           0.000000      4.000000      9.000000
# 50%            4.400000           2.000000      4.600000     21.000000
# 75%            4.700000           4.000000      4.900000     34.000000
# max            5.000000           5.000000      5.000000     40.000000
#
#        val_star_rating       country
# count     12261.000000  12261.000000
# mean          3.609844     10.015333
# std           1.614694      6.185450
# min           0.000000      0.000000
# 25%           3.500000      4.000000
# 50%           4.200000     10.000000
# 75%           4.700000     15.000000
# max           5.000000     20.000000

# %%
X=df.drop('list_price',axis=1)
y=df['list_price']

# %%
X
# Out:
#        ages  num_reviews  piece_count  play_star_rating  review_difficulty  \
# 0        19            2          277               4.0                  0
# 1        19            2          168               4.0                  2
# 2        19           11           74               4.3                  2
# 3         5           23         1032               3.6                  0
# 4         5           14          744               3.2                  1
# ...     ...          ...          ...               ...                ...
# 12256    23            6          341               4.4                  2
# 12257    23            8          217               4.1                  2
# 12258    23           18          233               4.6                  2
# 12259    20            1           48               5.0                  4
# 12260    20           11          109               4.5                  2
#
#        star_rating  theme_name  val_star_rating  country
# 0              4.5           0              4.0       20
# 1              5.0           0              4.0       20
# 2              4.3           0              4.1       20
# 3              4.6           1              4.3       20
# 4              4.6           1              4.1       20
# ...            ...         ...              ...      ...
# 12256          4.3          38              4.2       19
# 12257          3.6          38              4.1       19
# 12258          4.6          38              4.5       19
# 12259          5.0          38              5.0       19
# 12260          4.7          38              4.8       19
#
# [12261 rows x 9 columns]

# %%
y
# Out:
# 0        29.9900
# 1        19.9900
# 2        12.9900
# 3        99.9900
# 4        79.9900
#           ...
# 12256    36.5878
# 12257    24.3878
# 12258    24.3878
# 12259    12.1878
# 12260    12.1878
# Name: list_price, Length: 12261, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=6)

# %%
print('shape of dataframe',df.shape)
print('shape of X_train is',X_train.shape)
print('shape of y_train is',y_train.shape)
print(X_test)
print(X_train)
# Out:
# shape of dataframe (12261, 10)
# shape of X_train is (8582, 9)
# shape of y_train is (8582,)
#        ages  num_reviews  piece_count  play_star_rating  review_difficulty  \
# 9907     26            8          941               4.6                  0
# 5243     11            0           19               0.0                  5
# 8276     29           34         1376               4.0                  1
# 6501     26            0          369               0.0                  5
# 1619     11            1           19               3.0                  5
# ...     ...          ...          ...               ...                ...
# 2144     13            1           75               5.0                  5
# 7242     26           21          494               4.6                  0
# 11631    26            3           85               4.7                  2
# 4639     11            3           28               5.0                  2
# 7269      0            1          136               0.0                  5
#
#        star_rating  theme_name  val_star_rating  country
# 9907           4.6          33              4.3       16
# 5243           0.0          13              0.0        7
# 8276           4.3          34              3.8       12
# 6501           0.0          28              0.0        9
# 1619           4.0          13              4.0        0
# ...            ...         ...              ...      ...
# 2144           5.0          21              5.0        2
# 7242           4.5          38              4.8       10
# 11631          4.7          34              4.7       18
# 4639           5.0          13              4.5        6
# 7269           5.0           4              0.0       11
#
# [3679 rows x 9 columns]
#        ages  num_reviews  piece_count  play_star_rating  review_difficulty  \
# 5133      8          202         2469               4.7                  1
# 759      26            9          252               4.8                  0
# 3803     26           56          659               4.6                  0
# 6906     11            1           19               3.0                  5
# 7129      7           84         4016               4.5                  1
# ...     ...          ...          ...               ...                ...
# 8527     29           13          955               4.1                  0
# 4714     19            0          119               0.0                  5
# 10196    23            6           76               4.2                  2
# 8419      0            3          119               4.5                  2
# 2761     23            1           56               4.0                  2
#
#        star_rating  theme_name  val_star_rating  country
# 5133           4.9           9              4.7        7
# 759            4.6          39              4.6       20
# 3803           4.6          34              3.9        4
# 6906           4.0          13              4.0       10
# 7129           3.9          34              3.5       10
# ...            ...         ...              ...      ...
# 8527           3.7          10              3.0       13
# 4714           0.0          17              0.0        6
# 10196          4.5          12              3.4       15
# 8419           5.0           4              4.5       13
# 2761           5.0          12              5.0        3
#
# [8582 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# %%
cols = X_train.columns
cols
# Out:
# Index(['ages', 'num_reviews', 'piece_count', 'play_star_rating',
#        'review_difficulty', 'star_rating', 'theme_name', 'val_star_rating',
#        'country'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,20))
for i in range(0,3):
    for j in range(0,3): 
            col = cols[i*3 + j]
            axes[i,j].set_title(col)
            axes[i,j].scatter(X_train[col],y_train)
            axes[i,j].set_xlabel(col)
            axes[i,j].set_ylabel('list_price')
plt.show()

# %%
import seaborn as sns
# Out:
# C:\Users\Fakhruddin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#sns.pairplot(X_train)

# %%
corr=X_train.corr()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(corr,annot=True)

# %%
X_train.drop(['play_star_rating','val_star_rating'],1,inplace=True)
X_test.drop(['play_star_rating','val_star_rating'],1,inplace=True)
# Out:
# C:\Users\Fakhruddin\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=regressor.predict(X_test)

# %%
y_pred
# Out:
# array([115.7818155 ,  23.4896271 , 151.23855449, ...,  27.42257011,
#         15.68027757,  18.93585343])

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print('Mean Square error is: ',mse)
print('R2 Square is',r2)
# Out:
# Mean Square error is 2106.763431185767
# R2 Square is 0.7747160273433752
